# %% [markdown]
# # First tutorial
# ## This is an installation demo.
#
# - python is versatile
# - python is easy to learn
# - python is great for ds

# %%
print("Abhishek")
# Out:
# Abhishek

# %%
p=90
q=76
r=34
sum=(p+q+r)

# %%
print(sum)
# Out:
# 200
